# %%
# !pip install mediapipe

# %%
import cv2
import mediapipe as mp
import pandas as pd
import time
import os

# Khởi tạo thư viện MediaPipe
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_draw = mp.solutions.drawing_utils

# Mở webcam
cap = cv2.VideoCapture(0)

# Danh sách hành động cần thu thập
actions = ["dung_yen", "chay", "di_bo", "ngoi", "dam", "vay_tay"]
data = {action: [] for action in actions}
current_label = None  # Mặc định không ghi dữ liệu
recording = False  # Cờ kiểm soát trạng thái ghi

# Số khung hình cần thu thập mỗi hành động
no_of_frames = 600
frame_count = {action: 0 for action in actions}  # Đếm số frame đã thu thập
fps_limit = 60  # Giới hạn FPS
prev_time = 0

def extract_landmarks(results):
    """Trích xuất thông số khung xương từ MediaPipe."""
    if results.pose_landmarks:
        return [coord for lm in results.pose_landmarks.landmark for coord in (lm.x, lm.y, lm.z, lm.visibility)]
    return []

print("Nhấn số để bắt đầu ghi hành động:")
print("1: Đứng yên | 2: Chạy | 3: Đi bộ | 4: Ngồi | 5: Đấm | 6: Vẫy tay | SPACE: Dừng ghi | Q: Thoát ")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Giới hạn tốc độ FPS
    curr_time = time.time()
    if curr_time - prev_time < 1 / fps_limit:
        continue
    prev_time = curr_time

    # Xử lý ảnh với MediaPipe
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(frame_rgb)

    # Nếu đang ghi, trích xuất dữ liệu
    if recording and current_label is not None:
        lm = extract_landmarks(results)
        if lm:
            data[current_label].append(lm)
            frame_count[current_label] += 1  # Tăng số frame đã thu thập
            print(f"Đang ghi '{current_label.upper()}': {frame_count[current_label]}/{no_of_frames} frames")

            # Hiển thị trạng thái ghi dữ liệu trên màn hình
            cv2.putText(frame, f"Recording: {current_label.upper()} ({frame_count[current_label]}/{no_of_frames})",
                        (10, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

            # Nếu đủ 600 frames thì tự động dừng ghi
            if frame_count[current_label] >= no_of_frames:
                print(f"Đã thu thập đủ {no_of_frames} frames cho '{current_label.upper()}'!")
                recording = False

    # Vẽ khung xương lên ảnh
    if results.pose_landmarks:
        mp_draw.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                               mp_draw.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=4),
                               mp_draw.DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=4))

    # Hiển thị thông tin hành động hiện tại
    if current_label:
        cv2.putText(frame, f"Label: {current_label.upper()}", (10, 50),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    # Hiển thị hình ảnh
    cv2.imshow("Pose Detection", frame)

    # Chuyển đổi hành động khi nhấn phím
    key = cv2.waitKey(1) & 0xFF
    if key == ord('1'):
        current_label = "dung_yen"
        recording = True
    elif key == ord('2'):
        current_label = "chay"
        recording = True
    elif key == ord('3'):
        current_label = "di_bo"
        recording = True
    elif key == ord('4'):
        current_label = "ngoi"
        recording = True
    elif key == ord('5'):
        current_label = "dam"
        recording = True
    elif key == ord('6'):
        current_label = "vay_tay"
        recording = True
    elif key == ord(' '):  # Nhấn SPACE để dừng ghi
        recording = False
        print(f"⏸ Dừng ghi hành động '{current_label.upper()}'")
    elif key == ord('q'):
        break

# Lưu dữ liệu vào file CSV 
for action, lm_list in data.items():
    if lm_list:
        filename = f"{action}.csv"
        df = pd.DataFrame(lm_list)

        # Nếu file đã tồn tại, append dữ liệu vào
        if os.path.exists(filename):
            df.to_csv(filename, mode='a', header=False, index=False)
        else:
            df.to_csv(filename, index=False)

print("Dữ liệu đã lưu thành công!")
cap.release()
cv2.destroyAllWindows()
# Out:
# Nhấn số để bắt đầu ghi hành động:
# 1: Đứng yên | 2: Chạy | 3: Đi bộ | 4: Ngồi | 5: Nằm | 6: Đấm | 7: Vẫy tay | SPACE: Dừng ghi | Q: Thoát
# Đang ghi 'CHAY': 1/600 frames
# Đang ghi 'CHAY': 2/600 frames
# Đang ghi 'CHAY': 3/600 frames
# Đang ghi 'CHAY': 4/600 frames
# Đang ghi 'CHAY': 5/600 frames
# Đang ghi 'CHAY': 6/600 frames
# Đang ghi 'CHAY': 7/600 frames
# Đang ghi 'CHAY': 8/600 frames
# Đang ghi 'CHAY': 9/600 frames
# Đang ghi 'CHAY': 10/600 frames
# Đang ghi 'CHAY': 11/600 frames
# Đang ghi 'CHAY': 12/600 frames
# Đang ghi 'CHAY': 13/600 frames
# Đang ghi 'CHAY': 14/600 frames
# Đang ghi 'CHAY': 15/600 frames
# Đang ghi 'CHAY': 16/600 frames
# Đang ghi 'CHAY': 17/600 frames
# Đang ghi 'CHAY': 18/600 frames
# Đang ghi 'CHAY': 19/600 frames
# Đang ghi 'CHAY': 20/600 frames
# Đang ghi 'CHAY': 21/600 frames
# Đang ghi 'CHAY': 22/600 frames
# Đang ghi 'CHAY': 23/600 frames
# Đang ghi 'CHAY': 24/600 frames
# Đang ghi 'CHAY': 25/600 frames
# Đang ghi 'CHAY': 26/600 frames
# Đang ghi 'CHAY': 27/600 frames
# Đang ghi 'CHAY': 28/600 frames
# Đang ghi 'CHAY': 29/600 frames
# Đang ghi 'CHAY': 30/600 frames
# Đang ghi 'CHAY': 31/600 frames
# Đang ghi 'CHAY': 32/600 frames
# Đang ghi 'CHAY': 33/600 frames
# Đang ghi 'CHAY': 34/600 frames
# Đang ghi 'CHAY': 35/600 frames
# Đang ghi 'CHAY': 36/600 frames
# Đang ghi 'CHAY': 37/600 frames
# Đang ghi 'CHAY': 38/600 frames
# Đang ghi 'CHAY': 39/600 frames
# Đang ghi 'CHAY': 40/600 frames
# Đang ghi 'CHAY': 41/600 frames
# Đang ghi 'CHAY': 42/600 frames
# Đang ghi 'CHAY': 43/600 frames
# Đang ghi 'CHAY': 44/600 frames
# Đang ghi 'CHAY': 45/600 frames
# Đang ghi 'CHAY': 46/600 frames
# Đang ghi 'CHAY': 47/600 frames
# Đang ghi 'CHAY': 48/600 frames
# Đang ghi 'CHAY': 49/600 frames
# Đang ghi 'CHAY': 50/600 frames
# Đang ghi 'CHAY': 51/600 frames
# Đang ghi 'CHAY': 52/600 frames
# Đang ghi 'CHAY': 53/600 frames
# Đang ghi 'CHAY': 54/600 frames
# Đang ghi 'CHAY': 55/600 frames
# Đang ghi 'CHAY': 56/600 frames
# Đang ghi 'CHAY': 57/600 frames
# Đang ghi 'CHAY': 58/600 frames
# Đang ghi 'CHAY': 59/600 frames
# Đang ghi 'CHAY': 60/600 frames
# Đang ghi 'CHAY': 61/600 frames
# Đang ghi 'CHAY': 62/600 frames
# Đang ghi 'CHAY': 63/600 frames
# Đang ghi 'CHAY': 64/600 frames
# Đang ghi 'CHAY': 65/600 frames
# Đang ghi 'CHAY': 66/600 frames
# Đang ghi 'CHAY': 67/600 frames
# Đang ghi 'CHAY': 68/600 frames
# Đang ghi 'CHAY': 69/600 frames
# Đang ghi 'CHAY': 70/600 frames
# Đang ghi 'CHAY': 71/600 frames
# Đang ghi 'CHAY': 72/600 frames
# Đang ghi 'CHAY': 73/600 frames
# Đang ghi 'CHAY': 74/600 frames
# Đang ghi 'CHAY': 75/600 frames
# Đang ghi 'CHAY': 76/600 frames
# Đang ghi 'CHAY': 77/600 frames
# Đang ghi 'CHAY': 78/600 frames
# Đang ghi 'CHAY': 79/600 frames
# Đang ghi 'CHAY': 80/600 frames
# Đang ghi 'CHAY': 81/600 frames
# Đang ghi 'CHAY': 82/600 frames
# Đang ghi 'CHAY': 83/600 frames
# Đang ghi 'CHAY': 84/600 frames
# Đang ghi 'CHAY': 85/600 frames
# Đang ghi 'CHAY': 86/600 frames
# Đang ghi 'CHAY': 87/600 frames
# Đang ghi 'CHAY': 88/600 frames
# Đang ghi 'CHAY': 89/600 frames
# Đang ghi 'CHAY': 90/600 frames
# Đang ghi 'CHAY': 91/600 frames
# Đang ghi 'CHAY': 92/600 frames
# Đang ghi 'CHAY': 93/600 frames
# Đang ghi 'CHAY': 94/600 frames
# Đang ghi 'CHAY': 95/600 frames
# Đang ghi 'CHAY': 96/600 frames
# Đang ghi 'CHAY': 97/600 frames
# Đang ghi 'CHAY': 98/600 frames
# Đang ghi 'CHAY': 99/600 frames
# Đang ghi 'CHAY': 100/600 frames
# Đang ghi 'CHAY': 101/600 frames
# Đang ghi 'CHAY': 102/600 frames
# Đang ghi 'CHAY': 103/600 frames
# Đang ghi 'CHAY': 104/600 frames
# Đang ghi 'CHAY': 105/600 frames
# Đang ghi 'CHAY': 106/600 frames
# Đang ghi 'CHAY': 107/600 frames
# Đang ghi 'CHAY': 108/600 frames
# Đang ghi 'CHAY': 109/600 frames
# Đang ghi 'CHAY': 110/600 frames
# Đang ghi 'CHAY': 111/600 frames
# Đang ghi 'CHAY': 112/600 frames
# Đang ghi 'CHAY': 113/600 frames
# Đang ghi 'CHAY': 114/600 frames
# Đang ghi 'CHAY': 115/600 frames
# Đang ghi 'CHAY': 116/600 frames
# Đang ghi 'CHAY': 117/600 frames
# Đang ghi 'CHAY': 118/600 frames
# Đang ghi 'CHAY': 119/600 frames
# Đang ghi 'CHAY': 120/600 frames
# Đang ghi 'CHAY': 121/600 frames
# Đang ghi 'CHAY': 122/600 frames
# Đang ghi 'CHAY': 123/600 frames
# Đang ghi 'CHAY': 124/600 frames
# Đang ghi 'CHAY': 125/600 frames
# Đang ghi 'CHAY': 126/600 frames
# Đang ghi 'CHAY': 127/600 frames
# Đang ghi 'CHAY': 128/600 frames
# Đang ghi 'CHAY': 129/600 frames
# Đang ghi 'CHAY': 130/600 frames
# Đang ghi 'CHAY': 131/600 frames
# Đang ghi 'CHAY': 132/600 frames
# Đang ghi 'CHAY': 133/600 frames
# Đang ghi 'CHAY': 134/600 frames
# Đang ghi 'CHAY': 135/600 frames
# Đang ghi 'CHAY': 136/600 frames
# Đang ghi 'CHAY': 137/600 frames
# Đang ghi 'CHAY': 138/600 frames
# Đang ghi 'CHAY': 139/600 frames
# Đang ghi 'CHAY': 140/600 frames
# Đang ghi 'CHAY': 141/600 frames
# Đang ghi 'CHAY': 142/600 frames
# Đang ghi 'CHAY': 143/600 frames
# Đang ghi 'CHAY': 144/600 frames
# Đang ghi 'CHAY': 145/600 frames
# Đang ghi 'CHAY': 146/600 frames
# Đang ghi 'CHAY': 147/600 frames
# Đang ghi 'CHAY': 148/600 frames
# Đang ghi 'CHAY': 149/600 frames
# Đang ghi 'CHAY': 150/600 frames
# Đang ghi 'CHAY': 151/600 frames
# Đang ghi 'CHAY': 152/600 frames
# Đang ghi 'CHAY': 153/600 frames
# Đang ghi 'CHAY': 154/600 frames
# Đang ghi 'CHAY': 155/600 frames
# Đang ghi 'CHAY': 156/600 frames
# Đang ghi 'CHAY': 157/600 frames
# Đang ghi 'CHAY': 158/600 frames
# Đang ghi 'CHAY': 159/600 frames
# Đang ghi 'CHAY': 160/600 frames
# Đang ghi 'CHAY': 161/600 frames
# Đang ghi 'CHAY': 162/600 frames
# Đang ghi 'CHAY': 163/600 frames
# Đang ghi 'CHAY': 164/600 frames
# Đang ghi 'CHAY': 165/600 frames
# Đang ghi 'CHAY': 166/600 frames
# Đang ghi 'CHAY': 167/600 frames
# Đang ghi 'CHAY': 168/600 frames
# Đang ghi 'CHAY': 169/600 frames
# Đang ghi 'CHAY': 170/600 frames
# Đang ghi 'CHAY': 171/600 frames
# Đang ghi 'CHAY': 172/600 frames
# Đang ghi 'CHAY': 173/600 frames
# Đang ghi 'CHAY': 174/600 frames
# Đang ghi 'CHAY': 175/600 frames
# Đang ghi 'CHAY': 176/600 frames
# Đang ghi 'CHAY': 177/600 frames
# Đang ghi 'CHAY': 178/600 frames
# Đang ghi 'CHAY': 179/600 frames
# Đang ghi 'CHAY': 180/600 frames
# Đang ghi 'CHAY': 181/600 frames
# Đang ghi 'CHAY': 182/600 frames
# Đang ghi 'CHAY': 183/600 frames
# Đang ghi 'CHAY': 184/600 frames
# Đang ghi 'CHAY': 185/600 frames
# Đang ghi 'CHAY': 186/600 frames
# Đang ghi 'CHAY': 187/600 frames
# Đang ghi 'CHAY': 188/600 frames
# Đang ghi 'CHAY': 189/600 frames
# Đang ghi 'CHAY': 190/600 frames
# Đang ghi 'CHAY': 191/600 frames
# Đang ghi 'CHAY': 192/600 frames
# Đang ghi 'CHAY': 193/600 frames
# Đang ghi 'CHAY': 194/600 frames
# Đang ghi 'CHAY': 195/600 frames
# Đang ghi 'CHAY': 196/600 frames
# Đang ghi 'CHAY': 197/600 frames
# Đang ghi 'CHAY': 198/600 frames
# Đang ghi 'CHAY': 199/600 frames
# Đang ghi 'CHAY': 200/600 frames
# Đang ghi 'CHAY': 201/600 frames
# Đang ghi 'CHAY': 202/600 frames
# Đang ghi 'CHAY': 203/600 frames
# Đang ghi 'CHAY': 204/600 frames
# Đang ghi 'CHAY': 205/600 frames
# Đang ghi 'CHAY': 206/600 frames
# Đang ghi 'CHAY': 207/600 frames
# Đang ghi 'CHAY': 208/600 frames
# Đang ghi 'CHAY': 209/600 frames
# Đang ghi 'CHAY': 210/600 frames
# Đang ghi 'CHAY': 211/600 frames
# Đang ghi 'CHAY': 212/600 frames
# Đang ghi 'CHAY': 213/600 frames
# Đang ghi 'CHAY': 214/600 frames
# Đang ghi 'CHAY': 215/600 frames
# Đang ghi 'CHAY': 216/600 frames
# Đang ghi 'CHAY': 217/600 frames
# Đang ghi 'CHAY': 218/600 frames
# Đang ghi 'CHAY': 219/600 frames
# Đang ghi 'CHAY': 220/600 frames
# Đang ghi 'CHAY': 221/600 frames
# Đang ghi 'CHAY': 222/600 frames
# Đang ghi 'CHAY': 223/600 frames
# Đang ghi 'CHAY': 224/600 frames
# Đang ghi 'CHAY': 225/600 frames
# Đang ghi 'CHAY': 226/600 frames
# Đang ghi 'CHAY': 227/600 frames
# Đang ghi 'CHAY': 228/600 frames
# Đang ghi 'CHAY': 229/600 frames
# Đang ghi 'CHAY': 230/600 frames
# Đang ghi 'CHAY': 231/600 frames
# Đang ghi 'CHAY': 232/600 frames
# Đang ghi 'CHAY': 233/600 frames
# Đang ghi 'CHAY': 234/600 frames
# Đang ghi 'CHAY': 235/600 frames
# Đang ghi 'CHAY': 236/600 frames
# Đang ghi 'CHAY': 237/600 frames
# Đang ghi 'CHAY': 238/600 frames
# Đang ghi 'CHAY': 239/600 frames
# Đang ghi 'CHAY': 240/600 frames
# Đang ghi 'CHAY': 241/600 frames
# Đang ghi 'CHAY': 242/600 frames
# Đang ghi 'CHAY': 243/600 frames
# Đang ghi 'CHAY': 244/600 frames
# Đang ghi 'CHAY': 245/600 frames
# Đang ghi 'CHAY': 246/600 frames
# Đang ghi 'CHAY': 247/600 frames
# Đang ghi 'CHAY': 248/600 frames
# Đang ghi 'CHAY': 249/600 frames
# Đang ghi 'CHAY': 250/600 frames
# Đang ghi 'CHAY': 251/600 frames
# Đang ghi 'CHAY': 252/600 frames
# Đang ghi 'CHAY': 253/600 frames
# Đang ghi 'CHAY': 254/600 frames
# Đang ghi 'CHAY': 255/600 frames
# Đang ghi 'CHAY': 256/600 frames
# Đang ghi 'CHAY': 257/600 frames
# Đang ghi 'CHAY': 258/600 frames
# Đang ghi 'CHAY': 259/600 frames
# Đang ghi 'CHAY': 260/600 frames
# Đang ghi 'CHAY': 261/600 frames
# Đang ghi 'CHAY': 262/600 frames
# Đang ghi 'CHAY': 263/600 frames
# Đang ghi 'CHAY': 264/600 frames
# Đang ghi 'CHAY': 265/600 frames
# Đang ghi 'CHAY': 266/600 frames
# Đang ghi 'CHAY': 267/600 frames
# Đang ghi 'CHAY': 268/600 frames
# Đang ghi 'CHAY': 269/600 frames
# Đang ghi 'CHAY': 270/600 frames
# Đang ghi 'CHAY': 271/600 frames
# Đang ghi 'CHAY': 272/600 frames
# Đang ghi 'CHAY': 273/600 frames
# Đang ghi 'CHAY': 274/600 frames
# Đang ghi 'CHAY': 275/600 frames
# Đang ghi 'CHAY': 276/600 frames
# Đang ghi 'CHAY': 277/600 frames
# Đang ghi 'CHAY': 278/600 frames
# Đang ghi 'CHAY': 279/600 frames
# Đang ghi 'CHAY': 280/600 frames
# Đang ghi 'CHAY': 281/600 frames
# Đang ghi 'CHAY': 282/600 frames
# Đang ghi 'CHAY': 283/600 frames
# Đang ghi 'CHAY': 284/600 frames
# Đang ghi 'CHAY': 285/600 frames
# Đang ghi 'CHAY': 286/600 frames
# Đang ghi 'CHAY': 287/600 frames
# Đang ghi 'CHAY': 288/600 frames
# Đang ghi 'CHAY': 289/600 frames
# Đang ghi 'CHAY': 290/600 frames
# Đang ghi 'CHAY': 291/600 frames
# Đang ghi 'CHAY': 292/600 frames
# Đang ghi 'CHAY': 293/600 frames
# Đang ghi 'CHAY': 294/600 frames
# Đang ghi 'CHAY': 295/600 frames
# Đang ghi 'CHAY': 296/600 frames
# Đang ghi 'CHAY': 297/600 frames
# Đang ghi 'CHAY': 298/600 frames
# Đang ghi 'CHAY': 299/600 frames
# Đang ghi 'CHAY': 300/600 frames
# Đang ghi 'CHAY': 301/600 frames
# Đang ghi 'CHAY': 302/600 frames
# Đang ghi 'CHAY': 303/600 frames
# Đang ghi 'CHAY': 304/600 frames
# Đang ghi 'CHAY': 305/600 frames
# Đang ghi 'CHAY': 306/600 frames
# Đang ghi 'CHAY': 307/600 frames
# Đang ghi 'CHAY': 308/600 frames
# Đang ghi 'CHAY': 309/600 frames
# Đang ghi 'CHAY': 310/600 frames
# Đang ghi 'CHAY': 311/600 frames
# Đang ghi 'CHAY': 312/600 frames
# Đang ghi 'CHAY': 313/600 frames
# Đang ghi 'CHAY': 314/600 frames
# Đang ghi 'CHAY': 315/600 frames
# Đang ghi 'CHAY': 316/600 frames
# Đang ghi 'CHAY': 317/600 frames
# Đang ghi 'CHAY': 318/600 frames
# Đang ghi 'CHAY': 319/600 frames
# Đang ghi 'CHAY': 320/600 frames
# Đang ghi 'CHAY': 321/600 frames
# Đang ghi 'CHAY': 322/600 frames
# Đang ghi 'CHAY': 323/600 frames
# Đang ghi 'CHAY': 324/600 frames
# Đang ghi 'CHAY': 325/600 frames
# Đang ghi 'CHAY': 326/600 frames
# Đang ghi 'CHAY': 327/600 frames
# Đang ghi 'CHAY': 328/600 frames
# Đang ghi 'CHAY': 329/600 frames
# Đang ghi 'CHAY': 330/600 frames
# Đang ghi 'CHAY': 331/600 frames
# Đang ghi 'CHAY': 332/600 frames
# Đang ghi 'CHAY': 333/600 frames
# Đang ghi 'CHAY': 334/600 frames
# Đang ghi 'CHAY': 335/600 frames
# Đang ghi 'CHAY': 336/600 frames
# Đang ghi 'CHAY': 337/600 frames
# Đang ghi 'CHAY': 338/600 frames
# Đang ghi 'CHAY': 339/600 frames
# Đang ghi 'CHAY': 340/600 frames
# Đang ghi 'CHAY': 341/600 frames
# Đang ghi 'CHAY': 342/600 frames
# Đang ghi 'CHAY': 343/600 frames
# Đang ghi 'CHAY': 344/600 frames
# Đang ghi 'CHAY': 345/600 frames
# Đang ghi 'CHAY': 346/600 frames
# Đang ghi 'CHAY': 347/600 frames
# Đang ghi 'CHAY': 348/600 frames
# Đang ghi 'CHAY': 349/600 frames
# Đang ghi 'CHAY': 350/600 frames
# Đang ghi 'CHAY': 351/600 frames
# Đang ghi 'CHAY': 352/600 frames
# Đang ghi 'CHAY': 353/600 frames
# Đang ghi 'CHAY': 354/600 frames
# Đang ghi 'CHAY': 355/600 frames
# Đang ghi 'CHAY': 356/600 frames
# Đang ghi 'CHAY': 357/600 frames
# Đang ghi 'CHAY': 358/600 frames
# Đang ghi 'CHAY': 359/600 frames
# Đang ghi 'CHAY': 360/600 frames
# Đang ghi 'CHAY': 361/600 frames
# Đang ghi 'CHAY': 362/600 frames
# Đang ghi 'CHAY': 363/600 frames
# Đang ghi 'CHAY': 364/600 frames
# Đang ghi 'CHAY': 365/600 frames
# Đang ghi 'CHAY': 366/600 frames
# Đang ghi 'CHAY': 367/600 frames
# Đang ghi 'CHAY': 368/600 frames
# Đang ghi 'CHAY': 369/600 frames
# Đang ghi 'CHAY': 370/600 frames
# Đang ghi 'CHAY': 371/600 frames
# Đang ghi 'CHAY': 372/600 frames
# Đang ghi 'CHAY': 373/600 frames
# Đang ghi 'CHAY': 374/600 frames
# Đang ghi 'CHAY': 375/600 frames
# Đang ghi 'CHAY': 376/600 frames
# Đang ghi 'CHAY': 377/600 frames
# Đang ghi 'CHAY': 378/600 frames
# Đang ghi 'CHAY': 379/600 frames
# Đang ghi 'CHAY': 380/600 frames
# Đang ghi 'CHAY': 381/600 frames
# Đang ghi 'CHAY': 382/600 frames
# Đang ghi 'CHAY': 383/600 frames
# Đang ghi 'CHAY': 384/600 frames
# Đang ghi 'CHAY': 385/600 frames
# Đang ghi 'CHAY': 386/600 frames
# Đang ghi 'CHAY': 387/600 frames
# Đang ghi 'CHAY': 388/600 frames
# Đang ghi 'CHAY': 389/600 frames
# Đang ghi 'CHAY': 390/600 frames
# Đang ghi 'CHAY': 391/600 frames
# Đang ghi 'CHAY': 392/600 frames
# Đang ghi 'CHAY': 393/600 frames
# Đang ghi 'CHAY': 394/600 frames
# Đang ghi 'CHAY': 395/600 frames
# Đang ghi 'CHAY': 396/600 frames
# Đang ghi 'CHAY': 397/600 frames
# Đang ghi 'CHAY': 398/600 frames
# Đang ghi 'CHAY': 399/600 frames
# Đang ghi 'CHAY': 400/600 frames
# Đang ghi 'CHAY': 401/600 frames
# Đang ghi 'CHAY': 402/600 frames
# Đang ghi 'CHAY': 403/600 frames
# Đang ghi 'CHAY': 404/600 frames
# Đang ghi 'CHAY': 405/600 frames
# Đang ghi 'CHAY': 406/600 frames
# Đang ghi 'CHAY': 407/600 frames
# Đang ghi 'CHAY': 408/600 frames
# Đang ghi 'CHAY': 409/600 frames
# Đang ghi 'CHAY': 410/600 frames
# Đang ghi 'CHAY': 411/600 frames
# Đang ghi 'CHAY': 412/600 frames
# Đang ghi 'CHAY': 413/600 frames
# Đang ghi 'CHAY': 414/600 frames
# Đang ghi 'CHAY': 415/600 frames
# Đang ghi 'CHAY': 416/600 frames
# Đang ghi 'CHAY': 417/600 frames
# Đang ghi 'CHAY': 418/600 frames
# Đang ghi 'CHAY': 419/600 frames
# Đang ghi 'CHAY': 420/600 frames
# Đang ghi 'CHAY': 421/600 frames
# Đang ghi 'CHAY': 422/600 frames
# Đang ghi 'CHAY': 423/600 frames
# Đang ghi 'CHAY': 424/600 frames
# Đang ghi 'CHAY': 425/600 frames
# Đang ghi 'CHAY': 426/600 frames
# Đang ghi 'CHAY': 427/600 frames
# Đang ghi 'CHAY': 428/600 frames
# Đang ghi 'CHAY': 429/600 frames
# Đang ghi 'CHAY': 430/600 frames
# Đang ghi 'CHAY': 431/600 frames
# Đang ghi 'CHAY': 432/600 frames
# Đang ghi 'CHAY': 433/600 frames
# Đang ghi 'CHAY': 434/600 frames
# Đang ghi 'CHAY': 435/600 frames
# Đang ghi 'CHAY': 436/600 frames
# Đang ghi 'CHAY': 437/600 frames
# Đang ghi 'CHAY': 438/600 frames
# Đang ghi 'CHAY': 439/600 frames
# Đang ghi 'CHAY': 440/600 frames
# Đang ghi 'CHAY': 441/600 frames
# Đang ghi 'CHAY': 442/600 frames
# Đang ghi 'CHAY': 443/600 frames
# Đang ghi 'CHAY': 444/600 frames
# Đang ghi 'CHAY': 445/600 frames
# Đang ghi 'CHAY': 446/600 frames
# Đang ghi 'CHAY': 447/600 frames
# Đang ghi 'CHAY': 448/600 frames
# Đang ghi 'CHAY': 449/600 frames
# Đang ghi 'CHAY': 450/600 frames
# Đang ghi 'CHAY': 451/600 frames
# Đang ghi 'CHAY': 452/600 frames
# Đang ghi 'CHAY': 453/600 frames
# Đang ghi 'CHAY': 454/600 frames
# Đang ghi 'CHAY': 455/600 frames
# Đang ghi 'CHAY': 456/600 frames
# Đang ghi 'CHAY': 457/600 frames
# Đang ghi 'CHAY': 458/600 frames
# Đang ghi 'CHAY': 459/600 frames
# Đang ghi 'CHAY': 460/600 frames
# Đang ghi 'CHAY': 461/600 frames
# Đang ghi 'CHAY': 462/600 frames
# Đang ghi 'CHAY': 463/600 frames
# Đang ghi 'CHAY': 464/600 frames
# Đang ghi 'CHAY': 465/600 frames
# Đang ghi 'CHAY': 466/600 frames
# Đang ghi 'CHAY': 467/600 frames
# Đang ghi 'CHAY': 468/600 frames
# Đang ghi 'CHAY': 469/600 frames
# Đang ghi 'CHAY': 470/600 frames
# Đang ghi 'CHAY': 471/600 frames
# Đang ghi 'CHAY': 472/600 frames
# Đang ghi 'CHAY': 473/600 frames
# Đang ghi 'CHAY': 474/600 frames
# Đang ghi 'CHAY': 475/600 frames
# Đang ghi 'CHAY': 476/600 frames
# Đang ghi 'CHAY': 477/600 frames
# Đang ghi 'CHAY': 478/600 frames
# Đang ghi 'CHAY': 479/600 frames
# Đang ghi 'CHAY': 480/600 frames
# Đang ghi 'CHAY': 481/600 frames
# Đang ghi 'CHAY': 482/600 frames
# Đang ghi 'CHAY': 483/600 frames
# Đang ghi 'CHAY': 484/600 frames
# Đang ghi 'CHAY': 485/600 frames
# Đang ghi 'CHAY': 486/600 frames
# Đang ghi 'CHAY': 487/600 frames
# Đang ghi 'CHAY': 488/600 frames
# Đang ghi 'CHAY': 489/600 frames
# Đang ghi 'CHAY': 490/600 frames
# Đang ghi 'CHAY': 491/600 frames
# Đang ghi 'CHAY': 492/600 frames
# Đang ghi 'CHAY': 493/600 frames
# Đang ghi 'CHAY': 494/600 frames
# Đang ghi 'CHAY': 495/600 frames
# Đang ghi 'CHAY': 496/600 frames
# Đang ghi 'CHAY': 497/600 frames
# Đang ghi 'CHAY': 498/600 frames
# Đang ghi 'CHAY': 499/600 frames
# Đang ghi 'CHAY': 500/600 frames
# Đang ghi 'CHAY': 501/600 frames
# Đang ghi 'CHAY': 502/600 frames
# Đang ghi 'CHAY': 503/600 frames
# Đang ghi 'CHAY': 504/600 frames
# Đang ghi 'CHAY': 505/600 frames
# Đang ghi 'CHAY': 506/600 frames
# Đang ghi 'CHAY': 507/600 frames
# Đang ghi 'CHAY': 508/600 frames
# Đang ghi 'CHAY': 509/600 frames
# Đang ghi 'CHAY': 510/600 frames
# Đang ghi 'CHAY': 511/600 frames
# Đang ghi 'CHAY': 512/600 frames
# Đang ghi 'CHAY': 513/600 frames
# Đang ghi 'CHAY': 514/600 frames
# Đang ghi 'CHAY': 515/600 frames
# Đang ghi 'CHAY': 516/600 frames
# Đang ghi 'CHAY': 517/600 frames
# Đang ghi 'CHAY': 518/600 frames
# Đang ghi 'CHAY': 519/600 frames
# Đang ghi 'CHAY': 520/600 frames
# Đang ghi 'CHAY': 521/600 frames
# Đang ghi 'CHAY': 522/600 frames
# Đang ghi 'CHAY': 523/600 frames
# Đang ghi 'CHAY': 524/600 frames
# Đang ghi 'CHAY': 525/600 frames
# Đang ghi 'CHAY': 526/600 frames
# Đang ghi 'CHAY': 527/600 frames
# Đang ghi 'CHAY': 528/600 frames
# Đang ghi 'CHAY': 529/600 frames
# Đang ghi 'CHAY': 530/600 frames
# Đang ghi 'CHAY': 531/600 frames
# Đang ghi 'CHAY': 532/600 frames
# Đang ghi 'CHAY': 533/600 frames
# Đang ghi 'CHAY': 534/600 frames
# Đang ghi 'CHAY': 535/600 frames
# Đang ghi 'CHAY': 536/600 frames
# Đang ghi 'CHAY': 537/600 frames
# Đang ghi 'CHAY': 538/600 frames
# Đang ghi 'CHAY': 539/600 frames
# Đang ghi 'CHAY': 540/600 frames
# Đang ghi 'CHAY': 541/600 frames
# Đang ghi 'CHAY': 542/600 frames
# Đang ghi 'CHAY': 543/600 frames
# Đang ghi 'CHAY': 544/600 frames
# Đang ghi 'CHAY': 545/600 frames
# Đang ghi 'CHAY': 546/600 frames
# Đang ghi 'CHAY': 547/600 frames
# Đang ghi 'CHAY': 548/600 frames
# Đang ghi 'CHAY': 549/600 frames
# Đang ghi 'CHAY': 550/600 frames
# Đang ghi 'CHAY': 551/600 frames
# Đang ghi 'CHAY': 552/600 frames
# Đang ghi 'CHAY': 553/600 frames
# Đang ghi 'CHAY': 554/600 frames
# Đang ghi 'CHAY': 555/600 frames
# Đang ghi 'CHAY': 556/600 frames
# Đang ghi 'CHAY': 557/600 frames
# Đang ghi 'CHAY': 558/600 frames
# Đang ghi 'CHAY': 559/600 frames
# Đang ghi 'CHAY': 560/600 frames
# Đang ghi 'CHAY': 561/600 frames
# Đang ghi 'CHAY': 562/600 frames
# Đang ghi 'CHAY': 563/600 frames
# Đang ghi 'CHAY': 564/600 frames
# Đang ghi 'CHAY': 565/600 frames
# Đang ghi 'CHAY': 566/600 frames
# Đang ghi 'CHAY': 567/600 frames
# Đang ghi 'CHAY': 568/600 frames
# Đang ghi 'CHAY': 569/600 frames
# Đang ghi 'CHAY': 570/600 frames
# Đang ghi 'CHAY': 571/600 frames
# Đang ghi 'CHAY': 572/600 frames
# Đang ghi 'CHAY': 573/600 frames
# Đang ghi 'CHAY': 574/600 frames
# Đang ghi 'CHAY': 575/600 frames
# Đang ghi 'CHAY': 576/600 frames
# Đang ghi 'CHAY': 577/600 frames
# Đang ghi 'CHAY': 578/600 frames
# Đang ghi 'CHAY': 579/600 frames
# Đang ghi 'CHAY': 580/600 frames
# Đang ghi 'CHAY': 581/600 frames
# Đang ghi 'CHAY': 582/600 frames
# Đang ghi 'CHAY': 583/600 frames
# Đang ghi 'CHAY': 584/600 frames
# Đang ghi 'CHAY': 585/600 frames
# Đang ghi 'CHAY': 586/600 frames
# Đang ghi 'CHAY': 587/600 frames
# Đang ghi 'CHAY': 588/600 frames
# Đang ghi 'CHAY': 589/600 frames
# Đang ghi 'CHAY': 590/600 frames
# Đang ghi 'CHAY': 591/600 frames
# Đang ghi 'CHAY': 592/600 frames
# Đang ghi 'CHAY': 593/600 frames
# Đang ghi 'CHAY': 594/600 frames
# Đang ghi 'CHAY': 595/600 frames
# Đang ghi 'CHAY': 596/600 frames
# Đang ghi 'CHAY': 597/600 frames
# Đang ghi 'CHAY': 598/600 frames
# Đang ghi 'CHAY': 599/600 frames
# Đang ghi 'CHAY': 600/600 frames
# Đã thu thập đủ 600 frames cho 'CHAY'!
# Dữ liệu đã lưu thành công!
